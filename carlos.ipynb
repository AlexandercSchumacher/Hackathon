# %%
# CELL 1 – imports

import pandas as pd
import numpy as np

# %%
calendar = pd.read_csv("../Data/calendar.csv.gz", compression="gzip")
listings = pd.read_csv("../Data/listings.csv.gz", compression="gzip")
reviews  = pd.read_csv("../Data/reviews.csv.gz", compression="gzip")  # <-- IMPORTANT

print("calendar:", calendar.shape)
print("listings:", listings.shape)
print("reviews:", reviews.shape)

print(reviews.columns)  # quick check
# Out:
# calendar: (365, 7)
# listings: (2876, 79)
# reviews: (318549, 6)
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
# CELL 3 – basic cleaning (dates, prices, availability)

# --- calendar types ---
calendar['date'] = pd.to_datetime(calendar['date'])
calendar['available'] = calendar['available'].map({'t': 1, 'f': 0})

# price cleaner
def clean_price(x):
    try:
        return float(str(x).replace("$", "").replace(",", ""))
    except:
        return np.nan

calendar['price'] = calendar['price'].apply(clean_price)
calendar['adjusted_price'] = calendar['adjusted_price'].apply(clean_price)

# --- listings types ---
listings['last_review'] = pd.to_datetime(listings['last_review'], errors='coerce')
listings['price'] = listings['price'].apply(clean_price)

# --- reviews types ---
reviews['date'] = pd.to_datetime(reviews['date'], errors='coerce')

calendar.head()
# Out:
#            listing_id       date  available  price  adjusted_price  \
# 0  686088974677118082 2025-06-27          0    NaN             NaN
# 1  686088974677118082 2025-06-28          0    NaN             NaN
# 2  686088974677118082 2025-06-29          1    NaN             NaN
# 3  686088974677118082 2025-06-30          1    NaN             NaN
# 4  686088974677118082 2025-07-01          1    NaN             NaN
#
#    minimum_nights  maximum_nights
# 0               2            1125
# 1               2            1125
# 2               2            1125
# 3               2            1125
# 4               2            1125

# %%
# CELL 4 – select only useful columns

# from calendar
calendar_small = calendar[[
    "listing_id",
    "date",
    "available",        # target (later)
    "price",
    "adjusted_price",
    "minimum_nights",
    "maximum_nights"
]]

# from listings
listings_small = listings[[
    "id",
    "host_id",
    "neighbourhood",
    "latitude",
    "longitude",
    "room_type",
    "price",                    # listing's base price
    "number_of_reviews",
    "reviews_per_month",
    "calculated_host_listings_count",
    "availability_365",
    "last_review",
    "description",
    "neighborhood_overview",
    "amenities"
]]

calendar_small.head()
# Out:
#            listing_id       date  available  price  adjusted_price  \
# 0  686088974677118082 2025-06-27          0    NaN             NaN
# 1  686088974677118082 2025-06-28          0    NaN             NaN
# 2  686088974677118082 2025-06-29          1    NaN             NaN
# 3  686088974677118082 2025-06-30          1    NaN             NaN
# 4  686088974677118082 2025-07-01          1    NaN             NaN
#
#    minimum_nights  maximum_nights
# 0               2            1125
# 1               2            1125
# 2               2            1125
# 3               2            1125
# 4               2            1125

# %%
# CELL 5 – aggregate reviews per listing

reviews_agg = reviews.groupby("listing_id").agg(
    review_count=("id", "count"),
    avg_review_length=("comments", lambda x: x.astype(str).str.len().mean()),
    combined_text=("comments", lambda x: " ".join(x.astype(str)))
).reset_index()

reviews_agg.head()
# Out:
#    listing_id  review_count  avg_review_length  \
# 0      155305           454         212.200441
# 1      197263            87         196.827586
# 2      209068            67         415.522388
# 3      246315            53         387.339623
# 4      314540            35         328.685714
#
#                                        combined_text
# 0  We had a wonderful time! The cottage was very ...
# 1  Timothy was kind and clean. He let me come and...
# 2  Absolutely enjoyed our stay w/ Kevin and Anne....
# 3  This cabin was perfect! It's literally a log c...
# 4  We spent four nights in Tom's beautiful house....

# %%
# CELL 6 – merge everything into one unified DataFrame

# 1) calendar + listings (listing_id ↔ id)
df = calendar_small.merge(
    listings_small,
    left_on="listing_id",
    right_on="id",
    how="left"
)

# 2) add aggregated review stats
df = df.merge(
    reviews_agg,
    on="listing_id",
    how="left"
)

print("Unified df shape:", df.shape)
df.head()
# Out:
# Unified df shape: (365, 25)
#            listing_id       date  available  price_x  adjusted_price  \
# 0  686088974677118082 2025-06-27          0      NaN             NaN
# 1  686088974677118082 2025-06-28          0      NaN             NaN
# 2  686088974677118082 2025-06-29          1      NaN             NaN
# 3  686088974677118082 2025-06-30          1      NaN             NaN
# 4  686088974677118082 2025-07-01          1      NaN             NaN
#
#    minimum_nights  maximum_nights                  id   host_id  \
# 0               2            1125  686088974677118082  27538155
# 1               2            1125  686088974677118082  27538155
# 2               2            1125  686088974677118082  27538155
# 3               2            1125  686088974677118082  27538155
# 4               2            1125  686088974677118082  27538155
#
#              neighbourhood  ...  reviews_per_month  \
# 0  Neighborhood highlights  ...               2.42
# 1  Neighborhood highlights  ...               2.42
# 2  Neighborhood highlights  ...               2.42
# 3  Neighborhood highlights  ...               2.42
# 4  Neighborhood highlights  ...               2.42
#
#    calculated_host_listings_count availability_365  last_review  \
# 0                               1              163   2025-05-26
# 1                               1              163   2025-05-26
# 2                               1              163   2025-05-26
# 3                               1              163   2025-05-26
# 4                               1              163   2025-05-26
#
#                                          description  \
# 0  Come get away with these incredible views at 3...
# 1  Come get away with these incredible views at 3...
# 2  Come get away with these incredible views at 3...
# 3  Come get away with these incredible views at 3...
# 4  Come get away with these incredible views at 3...
#
#                                neighborhood_overview  \
# 0  Extremely quiet neighborhood walk that offers ...
# 1  Extremely quiet neighborhood walk that offers ...
# 2  Extremely quiet neighborhood walk that offers ...
# 3  Extremely quiet neighborhood walk that offers ...
# 4  Extremely quiet neighborhood walk that offers ...
#
#                                            amenities  review_count  \
# 0  ["Room-darkening shades", "Outdoor dining area...            85
# 1  ["Room-darkening shades", "Outdoor dining area...            85
# 2  ["Room-darkening shades", "Outdoor dining area...            85
# 3  ["Room-darkening shades", "Outdoor dining area...            85
# 4  ["Room-darkening shades", "Outdoor dining area...            85
#
#   avg_review_length                                      combined_text
# 0        206.152941  You simply can not beat the views at this extr...
# 1        206.152941  You simply can not beat the views at this extr...
# 2        206.152941  You simply can not beat the views at this extr...
# 3        206.152941  You simply can not beat the views at this extr...
# 4        206.152941  You simply can not beat the views at this extr...
#
# [5 rows x 25 columns]

# %%
 6. Basic cleaning of the merged dataset
# ------------------------------------------------------------

# Remove rows without target
df = df.dropna(subset=["available_target"])

# Identify numeric and categorical columns (excluding identifiers)
id_cols = ["listing_id", "date"]
target_col = "available_target"

numeric_cols = df.select_dtypes(include=["number"]).columns.tolist()
# Ensure we don't accidentally treat the target as a feature in this step
numeric_feature_cols = [c for c in numeric_cols if c not in [target_col]]

categorical_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()

# Fill numeric missing values with median (simple, robust strategy)
for col in numeric_feature_cols:
    median_value = df[col].median()
    df[col] = df[col].fillna(median_value)

# Fill categorical missing with "Unknown"
for col in categorical_cols:
    df[col] = df[col].fillna("Unknown").astype("category")

# %%
7. Optional: One-hot encode categorical features
# ------------------------------------------------------------
# For an ML-ready dataset, it is often convenient to convert categories to dummies.
# We keep listing_id and date as identifier columns and do NOT encode them.

categorical_to_encode = [c for c in categorical_cols if c not in id_cols]

ml_dataset = df.copy()

if len(categorical_to_encode) > 0:
    ml_dataset = pd.get_dummies(
        ml_dataset,
        columns=categorical_to_encode,
        drop_first=True  # avoid dummy trap
    )

print("Final ML dataset shape:", ml_dataset.shape)

# Show a preview
ml_dataset.head()

# %%
# CELL 7 – basic feature engineering

# ---- temporal features ----
df["year"] = df["date"].dt.year
df["month"] = df["date"].dt.month
df["day"] = df["date"].dt.day
df["day_of_week"] = df["date"].dt.dayofweek
df["is_weekend"] = df["day_of_week"].isin([5, 6]).astype(int)

# ---- recency features ----
df["days_since_last_review"] = (df["date"] - df["last_review"]).dt.days
df["days_since_last_review"] = df["days_since_last_review"].fillna(9999)

# ---- fill missing simple numeric values ----
df["review_count"] = df["review_count"].fillna(0)
df["avg_review_length"] = df["avg_review_length"].fillna(0)

df.head()
# Out:
#            listing_id       date  available  price_x  adjusted_price  \
# 0  686088974677118082 2025-06-27          0      NaN             NaN
# 1  686088974677118082 2025-06-28          0      NaN             NaN
# 2  686088974677118082 2025-06-29          1      NaN             NaN
# 3  686088974677118082 2025-06-30          1      NaN             NaN
# 4  686088974677118082 2025-07-01          1      NaN             NaN
#
#    minimum_nights  maximum_nights                  id   host_id  \
# 0               2            1125  686088974677118082  27538155
# 1               2            1125  686088974677118082  27538155
# 2               2            1125  686088974677118082  27538155
# 3               2            1125  686088974677118082  27538155
# 4               2            1125  686088974677118082  27538155
#
#              neighbourhood  ...  \
# 0  Neighborhood highlights  ...
# 1  Neighborhood highlights  ...
# 2  Neighborhood highlights  ...
# 3  Neighborhood highlights  ...
# 4  Neighborhood highlights  ...
#
#                                            amenities  review_count  \
# 0  ["Room-darkening shades", "Outdoor dining area...            85
# 1  ["Room-darkening shades", "Outdoor dining area...            85
# 2  ["Room-darkening shades", "Outdoor dining area...            85
# 3  ["Room-darkening shades", "Outdoor dining area...            85
# 4  ["Room-darkening shades", "Outdoor dining area...            85
#
#   avg_review_length                                      combined_text  year  \
# 0        206.152941  You simply can not beat the views at this extr...  2025
# 1        206.152941  You simply can not beat the views at this extr...  2025
# 2        206.152941  You simply can not beat the views at this extr...  2025
# 3        206.152941  You simply can not beat the views at this extr...  2025
# 4        206.152941  You simply can not beat the views at this extr...  2025
#
#    month  day  day_of_week is_weekend days_since_last_review
# 0      6   27            4          0                     32
# 1      6   28            5          1                     33
# 2      6   29            6          1                     34
# 3      6   30            0          0                     35
# 4      7    1            1          0                     36
#
# [5 rows x 31 columns]

# %%
# CELL 8 – prepare text columns (fill NaN with empty strings)

text_cols = ["description", "neighborhood_overview", "amenities", "combined_text"]

for col in text_cols:
    df[col] = df[col].fillna("")

df[text_cols].head()
# Out:
#                                          description  \
# 0  Come get away with these incredible views at 3...
# 1  Come get away with these incredible views at 3...
# 2  Come get away with these incredible views at 3...
# 3  Come get away with these incredible views at 3...
# 4  Come get away with these incredible views at 3...
#
#                                neighborhood_overview  \
# 0  Extremely quiet neighborhood walk that offers ...
# 1  Extremely quiet neighborhood walk that offers ...
# 2  Extremely quiet neighborhood walk that offers ...
# 3  Extremely quiet neighborhood walk that offers ...
# 4  Extremely quiet neighborhood walk that offers ...
#
#                                            amenities  \
# 0  ["Room-darkening shades", "Outdoor dining area...
# 1  ["Room-darkening shades", "Outdoor dining area...
# 2  ["Room-darkening shades", "Outdoor dining area...
# 3  ["Room-darkening shades", "Outdoor dining area...
# 4  ["Room-darkening shades", "Outdoor dining area...
#
#                                        combined_text
# 0  You simply can not beat the views at this extr...
# 1  You simply can not beat the views at this extr...
# 2  You simply can not beat the views at this extr...
# 3  You simply can not beat the views at this extr...
# 4  You simply can not beat the views at this extr...

# %%
# CELL 9 – final checks

print("Final dataset shape:", df.shape)
print("\nColumns:\n", df.columns.tolist())

# Optional: save intermediate version
# df.to_csv("airbnb_unified_features.csv", index=False)


print(df)
# Out:
# Final dataset shape: (365, 31)
#
# Columns:
#  ['listing_id', 'date', 'available', 'price_x', 'adjusted_price', 'minimum_nights', 'maximum_nights', 'id', 'host_id', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price_y', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'last_review', 'description', 'neighborhood_overview', 'amenities', 'review_count', 'avg_review_length', 'combined_text', 'year', 'month', 'day', 'day_of_week', 'is_weekend', 'days_since_last_review']
#              listing_id       date  available  price_x  adjusted_price  \
# 0    686088974677118082 2025-06-27          0      NaN             NaN
# 1    686088974677118082 2025-06-28          0      NaN             NaN
# 2    686088974677118082 2025-06-29          1      NaN             NaN
# 3    686088974677118082 2025-06-30          1      NaN             NaN
# 4    686088974677118082 2025-07-01          1      NaN             NaN
# ..                  ...        ...        ...      ...             ...
# 360  686088974677118082 2026-06-22          0      NaN             NaN
# 361  686088974677118082 2026-06-23          0      NaN             NaN
# 362  686088974677118082 2026-06-24          0      NaN             NaN
# 363  686088974677118082 2026-06-25          0      NaN             NaN
# 364  686088974677118082 2026-06-26          0      NaN             NaN
#
#      minimum_nights  maximum_nights                  id   host_id  \
# 0                 2            1125  686088974677118082  27538155
# 1                 2            1125  686088974677118082  27538155
# 2                 2            1125  686088974677118082  27538155
# 3                 2            1125  686088974677118082  27538155
# 4                 2            1125  686088974677118082  27538155
# ..              ...             ...                 ...       ...
# 360               2            1125  686088974677118082  27538155
# 361               2            1125  686088974677118082  27538155
# 362               2            1125  686088974677118082  27538155
# 363               2            1125  686088974677118082  27538155
# 364               2            1125  686088974677118082  27538155
#
#                neighbourhood  ...  \
# 0    Neighborhood highlights  ...
# 1    Neighborhood highlights  ...
# 2    Neighborhood highlights  ...
# 3    Neighborhood highlights  ...
# 4    Neighborhood highlights  ...
# ..                       ...  ...
# 360  Neighborhood highlights  ...
# 361  Neighborhood highlights  ...
# 362  Neighborhood highlights  ...
# 363  Neighborhood highlights  ...
# 364  Neighborhood highlights  ...
#
#                                              amenities  review_count  \
# 0    ["Room-darkening shades", "Outdoor dining area...            85
# 1    ["Room-darkening shades", "Outdoor dining area...            85
# 2    ["Room-darkening shades", "Outdoor dining area...            85
# 3    ["Room-darkening shades", "Outdoor dining area...            85
# 4    ["Room-darkening shades", "Outdoor dining area...            85
# ..                                                 ...           ...
# 360  ["Room-darkening shades", "Outdoor dining area...            85
# 361  ["Room-darkening shades", "Outdoor dining area...            85
# 362  ["Room-darkening shades", "Outdoor dining area...            85
# 363  ["Room-darkening shades", "Outdoor dining area...            85
# 364  ["Room-darkening shades", "Outdoor dining area...            85
#
#     avg_review_length                                      combined_text  \
# 0          206.152941  You simply can not beat the views at this extr...
# 1          206.152941  You simply can not beat the views at this extr...
# 2          206.152941  You simply can not beat the views at this extr...
# 3          206.152941  You simply can not beat the views at this extr...
# 4          206.152941  You simply can not beat the views at this extr...
# ..                ...                                                ...
# 360        206.152941  You simply can not beat the views at this extr...
# 361        206.152941  You simply can not beat the views at this extr...
# 362        206.152941  You simply can not beat the views at this extr...
# 363        206.152941  You simply can not beat the views at this extr...
# 364        206.152941  You simply can not beat the views at this extr...
#
#      year  month  day  day_of_week is_weekend days_since_last_review
# 0    2025      6   27            4          0                     32
# 1    2025      6   28            5          1                     33
# 2    2025      6   29            6          1                     34
# 3    2025      6   30            0          0                     35
# 4    2025      7    1            1          0                     36
# ..    ...    ...  ...          ...        ...                    ...
# 360  2026      6   22            0          0                    392
# 361  2026      6   23            1          0                    393
# 362  2026      6   24            2          0                    394
# 363  2026      6   25            3          0                    395
# 364  2026      6   26            4          0                    396
#
# [365 rows x 31 columns]
